# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("/kkd_weatherjuly.csv")
df1 = pd.read_csv("/amalapuram_weatherjuly.csv")
df2 = pd.read_csv("/vijayawada_weatherjuly.csv")

# %%
print(df2)
# Out:
#     Date  High Temperature  Low Tempature  Precipitation
# 0      1                33             28            0.0
# 1      2                33             27            4.3
# 2      3                33             28            0.0
# 3      4                32             25           18.0
# 4      5                30             25            2.8
# 5      6                29             24           23.1
# 6      7                36             27            0.0
# 7      8                35             27            0.0
# 8      9                34             25            0.0
# 9     10                34             26            1.5
# 10    11                35             25           18.5
# 11    12                35             27           43.9
# 12    13                34             26            6.1
# 13    14                32             26            0.0
# 14    15                30             25            5.1
# ...

# %%
print(df)
# Out:
#     Date  High Temperature  Low Temperature  Precipitation
# 0      1                32               27            0.0
# 1      2                33               26            0.0
# 2      3                31               27            0.0
# 3      4                30               25            4.0
# 4      5                29               25           10.0
# 5      6                29               24            2.0
# 6      7                35               26            0.0
# 7      8                34               28            0.0
# 8      9                33               24           59.0
# 9     10                33               25            3.0
# 10    11                33               25            0.0
# 11    12                35               25            6.0
# 12    13                33               25           46.0
# 13    14                32               25           15.0
# 14    15                28               25           14.0
# ...

# %%
print(df1)
# Out:
#     Date  High Temperature  Low Temperature  Precipitation
# 0      1                32               27            0.0
# 1      2                33               26            0.0
# 2      3                31               27            0.0
# 3      4                30               25            4.0
# 4      5                29               25           10.0
# 5      6                29               24            2.0
# 6      7                35               26            0.0
# 7      8                34               28            0.0
# 8      9                33               24           59.0
# 9     10                33               25            3.0
# 10    11                33               25            0.0
# 11    12                35               25            6.0
# 12    13                33               25           46.0
# 13    14                32               25           15.0
# 14    15                28               25           14.0
# ...

# %%
plt.plot(df['Date'],df['High Temperature'])
plt.title("Date vs High Temperature in kakinada",fontsize = 20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("High Temperature in degree celsius",fontsize=15)
# Out:
# Text(0, 0.5, 'High Temperature in degree celsius')

# %%
plt.plot(df['Date'],df['Low Temperature'])
plt.title("Date vs Low Temperature in kakinada",fontsize = 20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Low Temperature in degree celsius",fontsize=15)
# Out:
# Text(0, 0.5, 'Low Temperature in degree celsius')

# %%
plt.plot(df['Date'],df['Precipitation'])
plt.title("Date vs Precipitation in kakinada",fontsize = 20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Precipitation in mm",fontsize=15)
# Out:
# Text(0, 0.5, 'Precipitation in mm')

# %%
plt.subplot(2,1,1)
plt.plot(df['Date'],df['High Temperature'])
plt.title("Date vs High Temperature in kakinada",fontsize = 20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("High Temperature in degree celsius",fontsize=15)
plt.show()
plt.subplot(2,1,2)
plt.plot(df['Date'],df['Low Temperature'])
plt.title("Date vs Low Temperature in kakinada",fontsize = 20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Low Temperature in degree celsius",fontsize=15)
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(df['Date'],df['High Temperature'])
plt.title("Kakinada",fontsize = 20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("High Temperature in degree celsius",fontsize=15)
plt.show()
plt.subplot(2,1,1)
plt.plot(df1['Date'],df1['High Temperature'])
plt.title("Amalapuram",fontsize = 20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("High Temperature in degree celsius",fontsize=15)
plt.show()

# %%
plt.subplot(2,1,2)
plt.plot(df['Date'],df['Low Temperature'])
plt.title("Kakinada",fontsize = 20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Low Temperature in degree celsius",fontsize=15)
plt.show()
plt.subplot(2,1,2)
plt.plot(df1['Date'],df1['Low Temperature'])
plt.title("Amalapuram",fontsize = 20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Low Temperature in degree celsius",fontsize=15)
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(df['Date'],df['Precipitation'])
plt.title("Kakinada",fontsize = 20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Precipitation in mm",fontsize=15)
plt.show()
plt.subplot(2,1,1)
plt.plot(df1['Date'],df1['Precipitation'])
plt.title("Amalapuram",fontsize = 20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Precipitation in mm",fontsize=15)
plt.show()

# %%
plt.plot(df2['Date'],df2['High Temperature'])
plt.title("Date vs High Temp in Vijayawada",fontsize=20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("High Temp in degree celsius",fontsize=15)
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(df['Date'],df['High Temperature'])
plt.title("Kakinada",fontsize = 20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("High Temperature in degree celsius",fontsize=15)
plt.show()
plt.subplot(2,1,1)
plt.plot(df2['Date'],df1['High Temperature'])
plt.title("Vijayawada",fontsize = 20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("High Temperature in degree celsius",fontsize=15)
plt.show()
