# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/student_data.csv')

# %%
df
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   NaN  70.0        Good
# 2   3  88.0   NaN  Execellent
# 3   4   NaN  74.0         NaN
# 4   5  63.0   NaN     Average
# 5   6   NaN   NaN  Execellent
# 6   7   NaN   NaN         NaN
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
df.fillna(0)
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   0.0  70.0        Good
# 2   3  88.0   0.0  Execellent
# 3   4   0.0  74.0           0
# 4   5  63.0   0.0     Average
# 5   6   0.0   0.0  Execellent
# 6   7   0.0   0.0           0
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
new_df=df.fillna(
    {
        'CS':0,
     'Math':0,
     'Name':'no categery'
     
    }
)

new_df
# Out:
#    Id    CS  Math         Name
# 0   1  50.0  46.0      Average
# 1   2   0.0  70.0         Good
# 2   3  88.0   0.0   Execellent
# 3   4   0.0  74.0  no categery
# 4   5  63.0   0.0      Average
# 5   6   0.0   0.0   Execellent
# 6   7   0.0   0.0  no categery
# 7   8  53.0  45.0      Average
# 8   9  60.0  62.0         Good
# 9  10  55.0  65.0         Good

# %%
new_df=df.fillna(method="ffill")
new_df
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2  50.0  70.0        Good
# 2   3  88.0  70.0  Execellent
# 3   4  88.0  74.0  Execellent
# 4   5  63.0  74.0     Average
# 5   6  63.0  74.0  Execellent
# 6   7  63.0  74.0  Execellent
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
new_df=df.fillna(method="bfill")
new_df
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2  88.0  70.0        Good
# 2   3  88.0  74.0  Execellent
# 3   4  63.0  74.0     Average
# 4   5  63.0  45.0     Average
# 5   6  53.0  45.0  Execellent
# 6   7  53.0  45.0     Average
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
newdf=df.fillna(method='bfill',axis='columns') #index for row and and columns for columns
newdf
# Out:
#    Id          CS        Math        Name
# 0   1          50          46     Average
# 1   2          70          70        Good
# 2   3          88  Execellent  Execellent
# 3   4          74          74         NaN
# 4   5          63     Average     Average
# 5   6  Execellent  Execellent  Execellent
# 6   7         NaN         NaN         NaN
# 7   8          53          45     Average
# 8   9          60          62        Good
# 9  10          55          65        Good

# %% [markdown]
# ### **inplace
#
# > Indented block

# %%
qf=pd.read_csv('/content/student_data.csv')
qf
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   NaN  70.0        Good
# 2   3  88.0   NaN  Execellent
# 3   4   NaN  74.0         NaN
# 4   5  63.0   NaN     Average
# 5   6   NaN   NaN  Execellent
# 6   7   NaN   NaN         NaN
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
qf=df.fillna(method='ffill',limit=2,inplace=True)
qf

# %% [markdown]
# ### **interpolate,dropna**

# %%
af=pd.read_csv('/content/student_data.csv')
af
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   NaN  70.0        Good
# 2   3  88.0   NaN  Execellent
# 3   4   NaN  74.0         NaN
# 4   5  63.0   NaN     Average
# 5   6   NaN   NaN  Execellent
# 6   7   NaN   NaN         NaN
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
a=af.interpolate()
a
# Out:
#    Id         CS   Math        Name
# 0   1  50.000000  46.00     Average
# 1   2  69.000000  70.00        Good
# 2   3  88.000000  72.00  Execellent
# 3   4  75.500000  74.00         NaN
# 4   5  63.000000  66.75     Average
# 5   6  59.666667  59.50  Execellent
# 6   7  56.333333  52.25         NaN
# 7   8  53.000000  45.00     Average
# 8   9  60.000000  62.00        Good
# 9  10  55.000000  65.00        Good

# %%
b=af.dropna()
b
# Out:
#    Id    CS  Math     Name
# 0   1  50.0  46.0  Average
# 7   8  53.0  45.0  Average
# 8   9  60.0  62.0     Good
# 9  10  55.0  65.0     Good

# %%
b=af.dropna(how="all")
b
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   NaN  70.0        Good
# 2   3  88.0   NaN  Execellent
# 3   4   NaN  74.0         NaN
# 4   5  63.0   NaN     Average
# 5   6   NaN   NaN  Execellent
# 6   7   NaN   NaN         NaN
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
b=af.dropna(thresh=1)
b
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   NaN  70.0        Good
# 2   3  88.0   NaN  Execellent
# 3   4   NaN  74.0         NaN
# 4   5  63.0   NaN     Average
# 5   6   NaN   NaN  Execellent
# 6   7   NaN   NaN         NaN
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
b=af.dropna(thresh=2)
b
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   NaN  70.0        Good
# 2   3  88.0   NaN  Execellent
# 3   4   NaN  74.0         NaN
# 4   5  63.0   NaN     Average
# 5   6   NaN   NaN  Execellent
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
b=af.dropna(thresh=3)
b
# Out:
#    Id    CS  Math        Name
# 0   1  50.0  46.0     Average
# 1   2   NaN  70.0        Good
# 2   3  88.0   NaN  Execellent
# 4   5  63.0   NaN     Average
# 7   8  53.0  45.0     Average
# 8   9  60.0  62.0        Good
# 9  10  55.0  65.0        Good

# %%
b=af.replace(np.NaN,9999)
b
# Out:
#    Id      CS    Math        Name
# 0   1    50.0    46.0     Average
# 1   2  9999.0    70.0        Good
# 2   3    88.0  9999.0  Execellent
# 3   4  9999.0    74.0        9999
# 4   5    63.0  9999.0     Average
# 5   6  9999.0  9999.0  Execellent
# 6   7  9999.0  9999.0        9999
# 7   8    53.0    45.0     Average
# 8   9    60.0    62.0        Good
# 9  10    55.0    65.0        Good

# %%
c=af.replace(
    np.NaN,{
        'CS':444,
     'Math':0,
     'Name':'no'
    }
)
c
# Out:
#    Id     CS  Math        Name
# 0   1   50.0  46.0     Average
# 1   2  444.0  70.0        Good
# 2   3   88.0   0.0  Execellent
# 3   4  444.0  74.0          no
# 4   5   63.0   0.0     Average
# 5   6  444.0   0.0  Execellent
# 6   7  444.0   0.0          no
# 7   8   53.0  45.0     Average
# 8   9   60.0  62.0        Good
# 9  10   55.0  65.0        Good
